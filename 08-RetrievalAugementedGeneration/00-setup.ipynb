# %%
# %pip install --quiet --upgrade pip
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # download data sets

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.5 MB/s eta 0:00:09
#      --- ------------------------------------ 1.0/12.8 MB 1.5 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.3/12.8 MB 1.6 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.8/12.8 MB 1.7 MB/s eta 0:00:07
#      ------- -------------------------------- 2.4/12.8 MB 1.8 MB/s eta 0:00:06
#      --------- ------------------------------ 2.9/12.8 MB 1.9 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.4/12.8 MB 2.0 MB/s eta 0:00:05
#      ------------ --------------------------- 3.9/12.8 MB 2.1 MB/s eta 0:00:05
#      ------------- -------------------------- 4.5/12.8 MB 2.2 MB/s eta 0:00:04
# ...

# %%
from helpers import get_book
import langchain

for id in [244, 1342, 135, 34811, 13951, 27729, 23585]:
    get_book(id)
# Out:
# loading metadata from https://www.gutenberg.org/ebooks/244
# loading text from http://aleph.gutenberg.org/2/4/244/244.txt
# loading text from http://aleph.gutenberg.org/2/4/244/244-0.txt
# wrote book to cache: books/244.json
# wrote book to cache: books/244.txt
# loading metadata from https://www.gutenberg.org/ebooks/1342
# loading text from http://aleph.gutenberg.org/1/3/4/1342/1342.txt
# loading text from http://aleph.gutenberg.org/1/3/4/1342/1342-0.txt
# wrote book to cache: books/1342.json
# wrote book to cache: books/1342.txt
# loading metadata from https://www.gutenberg.org/ebooks/135
# loading text from http://aleph.gutenberg.org/1/3/135/135.txt
# loading text from http://aleph.gutenberg.org/1/3/135/135-0.txt
# wrote book to cache: books/135.json
# wrote book to cache: books/135.txt
# loading metadata from https://www.gutenberg.org/ebooks/34811
# loading text from http://aleph.gutenberg.org/3/4/8/1/34811/34811.txt
# ...

# %%
from helpers import get_pdf_from_uri

uris = [
    "https://dmi.unibas.ch/fileadmin/user_upload/dmi/Studium/Computer_Science/Vorlesungen_HS23/Multimedia_Retrieval/HS25/01_Introduction.pdf",
    "https://dmi.unibas.ch/fileadmin/user_upload/dmi/Studium/Computer_Science/Vorlesungen_HS23/Multimedia_Retrieval/HS25/02_ClassicalTextRetrieval.pdf",
    "https://dmi.unibas.ch/fileadmin/user_upload/dmi/Studium/Computer_Science/Vorlesungen_HS23/Multimedia_Retrieval/HS25/03_PerformanceEvaluation.pdf",
    "https://dmi.unibas.ch/fileadmin/user_upload/dmi/Studium/Computer_Science/Vorlesungen_HS23/Multimedia_Retrieval/HS25/04_AdvancedTextProcessing.pdf",
]

for uri in uris:
    get_pdf_from_uri(uri)
# Out:
# File downloaded and saved as pdfs/01_Introduction.pdf
# File downloaded and saved as pdfs/02_ClassicalTextRetrieval.pdf
# File downloaded and saved as pdfs/03_PerformanceEvaluation.pdf
# File downloaded and saved as pdfs/04_AdvancedTextProcessing.pdf

# %% [markdown]
# ---
